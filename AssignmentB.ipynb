# %% [markdown]
# # Assignment B: The Green Buffer
# This notebook contains the core logic for the 'Green Buffer' analysis.
# The data pipeline has been modularized into the following scripts:
# 1. `prepare_sample.py`: Extracts a representative sample of recent sales.
# 2. `geocode_sample.py`: Geocodes addresses using the DAWA API.
# 3. `calculate_nature_distance.py`: Calculates distance to protected nature areas using UTM 32N projection.
# 4. `create_final_dataset.py`: Computes price residuals (deviation from municipal median) and merges all features.
# 5. `generate_final_*.py`: Generates the visualizations for the website.

# %%
import pandas as pd
df = pd.read_csv('final_viz_data.csv')
df.head()
